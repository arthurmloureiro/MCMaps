# %% [markdown]
# #Using Gaussian Realizations of the density Field $\delta (\vec{x})$ to generate Maps of Galaxies and analize it with **FKP**
#
#
#
# ### *Arthur E. M. Loureiro & Lucas F. Secco*
#
# ### **18/07/2014**
#
# ###***IFUSP***

# %%
import numpy as np
import grid3D as gr
import sys
from time import clock
from scipy import interpolate
import pylab as pl
from matplotlib import cm
import fkp_class as fkpc
import gauss_pk_class as pkgauss

# %% [markdown]
# Reading the input file and converting the data

# %%
#init = clock()
camb_file, cell_size, n_x, n_y, n_z, num_realiz, bias, num_bins, n_bar, realiz_type = np.loadtxt('input2.dat', dtype=str)
cell_size = float(cell_size); n_x=int(n_x); n_y=int(n_y); n_z=int(n_z); num_realiz=int(num_realiz); bias=float(bias) ; num_bins=int(num_bins); realiz_type = int(realiz_type); n_bar = float(n_bar);

# %% [markdown]
# Reading **Camb's** file
# $P(k=0)=0$

# %%
k_camb , Pk_camb = np.loadtxt(camb_file, unpack=True)
k_camb = np.insert(k_camb,0,0.)						
Pk_camb = np.insert(Pk_camb,0,0.)
#Pk_camb_interp = interpolate.InterpolatedUnivariateSpline(k_camb,Pk_camb)	     #interpolate camb's Power Spectrum

# %% [markdown]
# Calculating $V_{box}$ and generating the Grids

# %%
L_x = n_x*cell_size ; L_y = n_y*cell_size ; L_z = n_z*cell_size 		     # size of the box
box_vol = L_x*L_y*L_z								     # Box's volume
L_max = np.sqrt(L_x*L_x + L_y*L_y + L_z*L_z)	

print("Generating the k-space Grid...\n")
grid = gr.grid3d(n_x,n_y,n_z,L_x,L_y,L_z)					     # generates the grid
grid_bins = gr.grid3d(num_bins, num_bins, num_bins, L_x,L_y,L_z)		     # generates the bins grid
										     # multiplying the grid for the cell_size will give us a grid in physical units 
pl.figure(figsize=(10,10))
pl.subplot(2,2,1)
pl.title("k-grid")
pl.imshow(grid.grid_k[2],cmap=cm.jet)
pl.subplot(2,2,2)
pl.title("r-grid")
pl.imshow(grid.grid_r[2],cmap=cm.jet)
# Out:
# Generating the k-space Grid...

# %% [markdown]
# This will be used to calculate $P_G(k)$ using a $k_{step} = \frac{1}{(1.1) L_{max}}$, $k_{max} = \frac{2\pi}{L_{cell}} $ where $L_{max} = \sqrt{L_x^2 + L_y^2 + L_z^2}$ is the diagonal of the box

# %%
kk_bar = np.fft.fftfreq(n_x)
kminbar = np.min(abs(kk_bar))
kmaxbar = np.sqrt(1.7)*np.max(abs(kk_bar))
dk_bar = kmaxbar/(num_bins+0.0001)*np.ones(num_bins)
k_bar = (dk_bar/2)+np.linspace(0.,kmaxbar-dk_bar[2],num_bins)
#dk_bar = np.diff(k_bar)
#dk_bar = np.pi/L_max
#print np.asarray([k_bar-dk_bar/2,k_bar+dk_bar/2]).T
print k_bar+ dk_bar/2.
#print len(k_bar)
#print dk_bar
#print fkp_stuff.k_bins
# Out:
# [ 0.03621759  0.07243539  0.1086532   0.144871    0.1810888   0.2173066
#   0.25352441  0.28974221  0.32596001  0.36217782  0.39839562  0.43461342
#   0.47083123  0.50704903  0.54326683  0.57948463  0.61570244  0.65192024]

# %%
# %time M = np.asarray([0.5*(np.sign((k_bar[a]+dk_bar[a]/2)-grid.grid_k[:,:,:n_x/2+1])+1.)*0.5*(np.sign(grid.grid_k[:,:,:n_x/2+1]-(k_bar[a]-dk_bar[a]/2))+1.)for a in range(len(k_bar))])
# Out:
# CPU times: user 32 ms, sys: 8 ms, total: 40 ms
# Wall time: 40.2 ms

# %% [raw]
# print np.max(M[12,:,:,:])
# print k_bar[20]
# print np.max(grid.grid_k)

# %%
pl.figure("K bins",figsize=(8,8))
pl.subplot(221)
numb =np.random.random_integers(0,num_bins-1)
pl.title("Showing bin number: " + str(numb) + " of " + str(num_bins))
pl.imshow(M[numb,0,:,:])
pl.colorbar()
pl.subplot(222)
numb =np.random.random_integers(0,num_bins-1)
pl.title("Showing bin number: " + str(numb) + " of " + str(num_bins))
pl.imshow(M[numb,:,0,:])
pl.colorbar()
pl.subplot(223)
numb =np.random.random_integers(0,num_bins-1)
pl.title("Showing bin number: " + str(numb) + " of " + str(num_bins))
pl.imshow(M[numb,:,:,0])
pl.colorbar()
pl.subplot(224)
numb =np.random.random_integers(0,num_bins-1)
pl.title("Showing bin number: " + str(numb) + " of " + str(num_bins))
pl.imshow(M[numb,0,:,:])
pl.colorbar()
pl.show()
print len(np.einsum("aijl->a", M))
# Out:
# 18

# %% [raw]
# print np.sum(np.einsum("aijl->a", M))
# print n_x*n_y*(n_z/2+1)
# print np.max(np.einsum("aijl->ijl", M)) , np.min(np.einsum("aijl->ijl", M))
# print np.einsum("aijl->a", M)

# %% [raw]
# Nxyz=np.einsum("aijl->ijl", M).flatten()
# pl.hist(Nxyz)
# Na = np.einsum("aijl->a", M)
# pl.figure()
# pl.plot(k_bar,Na)

# %%
# %%time
#def n_bar_func(gridr,n_,r0_,r1_,a_):
def n_bar_func(gridr,a_,b_):
    return a_*np.exp(-b_*gridr)
    #return n_*(1.+a_*np.sin(gridr/r0_))*np.exp(-gridr/r1_)
#n_bar_matrix = n_bar_func(grid.grid_r,n_bar,15,200.,0.9)
n_bar_matrix = n_bar_func(grid.grid_r, n_bar,0.04)
#n_bar_matrix = n_bar*np.ones((n_x,n_y,n_z))
pl.imshow(n_bar_matrix[2])
pl.colorbar()
# Out:
# CPU times: user 92 ms, sys: 0 ns, total: 92 ms
# Wall time: 92.9 ms

# %%
# %%time
#n_bar_matrix = np.ones((n_x,n_x,n_x))*n_bar
fkp_stuff = fkpc.fkp_init(num_bins,n_bar_matrix,bias,cell_size,n_x,n_y,n_z,M)
#print fkp_stuff.w
# Out:
# CPU times: user 8 ms, sys: 0 ns, total: 8 ms
# Wall time: 10.2 ms

# %% [markdown]
# Finding $\xi_{camb}(r) = \int dk ... P(k)sin(kr)/k$

# %% [markdown]
# Calculating $P_G(k)$

# %%
# %%time
pkg = pkgauss.gauss_pk(k_camb,Pk_camb,grid.grid_k,cell_size,L_max)
# Out:
# CPU times: user 84 ms, sys: 32 ms, total: 116 ms
# Wall time: 115 ms

# %% [markdown]
# Ploting $\xi_{camb}(r)$ in a limited useful range

# %%
pl.figure()
pl.grid(1)
pl.xlim(0,200)
pl.plot(pkg.r_k,(pkg.r_k*pkg.r_k)*pkg.corr_ln)

# %% [markdown]
# This plot shows both $P_{camb}(k)$, $P_{G}(k)$ and $P_{camb}(k)e^{-(k/2k_{max})^{-6}}$

# %%
pl.figure(figsize=(8,6))
pl.loglog() 
pl.ylim(1E-3,10E6)
pl.plot(k_camb, pkg.Pk_camb_interp(k_camb))
pl.plot(k_camb, pkg.Pk_camb_interp(k_camb)*np.exp(-1.0*np.power(k_camb/(3.*pkg.k_max),6.0)))
#pl.plot(k_r, Pk_gauss_interp(k_r),'--' ,linewidth=2.5)
pl.plot(pkg.k_r, pkg.Pk_gauss_interp(pkg.k_r),'-.k' ,linewidth=2.5)
pl.axvline(x=np.max(grid.grid_k), linewidth=2., color='r')
pl.axvline(x=np.min(grid.grid_k[grid.grid_k!=0.0]), linewidth=2., color='g')
#pl.plot(k_r,Pk_gauss)

# %%
# %%time
k_flat = grid.grid_k.flatten()*(2.*np.pi*n_x/L_x)                 #this norm factor is so we can have physical unities
Pk_flat = pkg.Pk_gauss_interp(k_flat)
#print k_flat.reshape((n_x,n_y,n_z))==grid.grid_k
p_matrix = Pk_flat.reshape((n_x,n_y,n_z))
p_matrix[0][0][0] = 1. 						     # Needs to be 1.
# Out:
# CPU times: user 4 ms, sys: 0 ns, total: 4 ms
# Wall time: 3.45 ms

# %% [markdown]
# Let us difine the **p.d.f.** s and some useful functions
#
# First, the **Gaussian Amplitude** with $\sigma_k = \sqrt{2P(k)V_{box}}$
#
# $\mathbb{P}(A_k) = \frac{1}{\sigma_k}exp( -A_k^2/\sigma_k^2)$

# %%
def A_k(P_):									 
	#################################################################################
	# The Gaussian Amplitude
	# Zero Medium and STD=SQRT(2*P(k)*Volume)
	# It must have the 2 factor to take the complex part into account after the iFFT
	#################################################################################
	return np.random.normal(0.0,np.sqrt(2.*P_*box_vol))

# %% [markdown]
# Random regular phase $\mathbb{P}(\phi_k)$

# %%
def phi_k(P_): 									     	
	######################
	# Random regular phase
	######################
	return (np.random.random(len(P_)))*2.*np.pi

# %% [markdown]
# The density constrast in Fourier Space $\delta_k = A_k e^{-i\phi}$

# %%
def delta_k_g(P_):								     
	########################################	
	# The density contrast in Fourier Space
	########################################
	return A_k(P_)*np.exp(1j*phi_k(P_))

# %% [markdown]
# The Log-Normal density Field $\delta_{ln} = exp(b\delta_g - b^2\sigma_g/2) -1$

# %%
def delta_x_ln(d_,sigma_,bias_):
	###############################
	# The log-normal density field
	###############################
	return np.exp(bias_*d_ - ((bias_**2.)*(sigma_))/2.0) -1.

# %% [markdown]
# Now, the loops being for both **Gaussian** or **Gaussian + Poissonian** Realizations

# %% [markdown]
# ## For both Gaussian + Poissonian Realizations or Poissonian only

# %%
# %%time
P_all = np.zeros((num_bins, num_realiz))
sigma_all = np.zeros((num_bins, num_realiz))
#Nr_all = np.zeros((num_bins, num_realiz))
if realiz_type == 1:
	print "Doing both Gaussian + Poissonian realizations... \n"
	for m in range(num_realiz):
            #########################
            # gaussian density field
            #########################
            delta_x_gaus = ((delta_k_g(p_matrix).size)/box_vol)*np.fft.ifftn(delta_k_g(p_matrix))	#the iFFT
            var_gr = np.var(delta_x_gaus.real)
            var_gi = np.var(delta_x_gaus.imag)
            delta_xr_g = delta_x_gaus.real
            delta_xi_g = delta_x_gaus.imag
            ###########################
            # Log-Normal Density Field
            ###########################
            delta_xr = delta_x_ln(delta_xr_g, var_gr,bias)
            delta_xi = delta_x_ln(delta_xi_g, var_gi,bias)
            #######################
            #poissonian realization
            #######################
            N_r = np.random.poisson(n_bar_matrix*(1.+delta_xr))#*(cell_size**3.))			     # This is the final galaxy Map
            N_i = np.random.poisson(n_bar_matrix*(1.+delta_xi))#*(cell_size**3.))
            ##########################################
            #                  FKP                   #
            ##########################################
            #print m
            FKP = fkp_stuff.fkp(N_r)
            #print m
            P = fkp_stuff.P_ret
            sigma = fkp_stuff.sigma
            P_all[:,m] = P
            sigma_all[:,m] = sigma
            print m
		
	print "\nDone.\n"
elif realiz_type == 2:
	print "Doing Poissonian realizations only \n"
	#########################
	# gaussian density field
	#########################
	delta_x_gaus = ((delta_k_g(p_matrix).size)/box_vol)*np.fft.ifftn(delta_k_g(p_matrix))	#the iFFT
	var_gr = np.var(delta_x_gaus.real)
	var_gi = np.var(delta_x_gaus.imag)
	delta_xr_g = delta_x_gaus.real
	delta_xi_g = delta_x_gaus.imag
	###########################
	# Log-Normal Density Field
	###########################
	delta_xr = delta_x_ln(delta_xr_g, var_gr,bias)
	delta_xi = delta_x_ln(delta_xi_g, var_gi,bias)
	for m in range(num_realiz):
            print m
            N_r = np.random.poisson(n_bar_matrix*(1.+delta_xr))#*(cell_size**3.))			     # This is the final galaxy Map
            N_i = np.random.poisson(n_bar_matrix*(1.+delta_xi))#*(cell_size**3.))
            print m
            FKP = fkp_stuff.fkp(N_r)
            print m
            P = fkp_stuff.P_ret
            sigma = fkp_stuff.sigma
            P_all[:,m] = P
            sigma_all[:,m] = sigma
            print m

	print "\nDone.\n" 
else:
	print "Error, invalid option for realization's type \n"
	sys.exit(-1)
# Out:
# Doing both Gaussian + Poissonian realizations...
#
# 0
#
# Done.
#
# CPU times: user 32 ms, sys: 0 ns, total: 32 ms
# Wall time: 31.3 ms

# %%
P_av = (1./num_realiz)*np.sum(P_all, axis=1)
P_sig = np.sqrt((1./num_realiz)*(np.sum(P_all**2, axis=1))-P_av**2)
P_avsig = (1./num_realiz)*np.sum(sigma_all, axis=1)
print P_av[0:3]
print P_sig[0:3]
print P_avsig[0:3]
print len(P_av)
print len(k_bar)
# Out:
# [ 41785.06023162  35903.81447188  22574.25500139]
# [ 0.  0.  0.]
# [ 220138.28578701   78054.88003675   35463.68622625]
# 18
# 18

# %%
pl.figure('P(k) zoom',figsize=(10,8))
pl.loglog()
pl.plot(k_camb,Pk_camb,label='CAMB',linewidth=1.5)
pl.xlim(1E-3,2.0)
pl.ylim(5E2,1E5)
pl.errorbar(k_bar*(2.*np.pi*n_x/L_x),P_av,yerr=P_sig,label='Mean Estimated P(k)')
#pl.errorbar(k_bar*(2.*np.pi*n_x/L_x),P_av,yerr=P_avsig,label='Mean Estimated P(k) 2')
pl.errorbar(k_bar*(2.*np.pi*n_x/L_x),P_av,yerr=P_avsig/10.,label='Mean Estimated P(k) 2/10')

#pl.plot(k[:],fkp_stuff.P_ret2[:])#*2800)
pl.xlabel(r'$k$ [h/Mpc]',fontsize=20)
pl.xlabel(r'$P(k)$ [Mpc/h]$^3$',fontsize=20)
pl.grid(True)
pl.axvline(x=np.max(np.max(grid.k_x)*(2.*np.pi*n_x/L_x)),color='k',label='Nyquist f.')
pl.legend()

# %%
N_flat = N_r.flatten()
#print N_flat.reshape(n_x,n_y,n_z) == N_r
np.savetxt("map_fid_new.dat", N_flat.T, fmt='%i')
#file.write("%i"%int(N_flat))

# %%
NN = np.loadtxt("map_fid_new.dat")
NN == N_flat
print N_flat
# Out:
# [4 9 0 ..., 2 5 0]

# %% [raw]
# pl.loglog()
# pl.plot(P_sig)
# pl.plot(P_avsig/10)

# %% [raw]
# pl.figure(figsize=(10,10))
# pl.loglog()
# pl.xlim(1E-3,0.4)
# pl.ylim(1E3,1E5)
# pl.axvline(x=np.max(np.max(grid.k_x)*(2.*np.pi*n_x/L_x)),color='k',label='Nyquist f.')
# pl.plot(k_camb,Pk_camb,label='CAMB',linewidth=1.5)
# for i in range(num_realiz-3):
#     pl.plot(k_bar*(2.*np.pi*n_x/L_x),P_all[:,i],'--y')
# pl.errorbar(k_bar*(2.*np.pi*n_x/L_x),P_av,yerr=P_sig,linewidth=2.3,label='Mean Estimated P(k)')
# pl.errorbar(k_bar*(2.*np.pi*n_x/L_x),P_av,yerr=P_avsig/10.,ecolor="green",linewidth=1.3,label='Mean Estimated P(k) 2')

# %%
#print "time = " + str(final - inicial)		
pl.figure(figsize=(10,10))
pl.subplot(2,2,1)
pl.imshow(N_r[5], cmap=cm.jet)
pl.colorbar()
pl.subplot(2,2,2)
pl.imshow(N_r[:,0,:], cmap=cm.jet)
pl.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x114b12fc8>

# %% [raw]
# #pl.subplot(21)
# pl.figure('P(k)',figsize=(8,8))
# pl.loglog()
# pl.plot(k_camb,Pk_camb,label='CAMB',linewidth=1.5)
# pl.errorbar(k,P,yerr=sigma,label='Estimated P(k)')
# #pl.plot(k[:],fkp_stuff.P_ret2[:])#*2800)
# pl.xlabel(r'$k$ [h/Mpc]',fontsize=20)
# pl.xlabel(r'$P(k)$ [Mpc/h]$^3$',fontsize=20)
# pl.grid(True)
# pl.axvline(x=pkg.k_max/2.,color='k',label='Nyquist f.')
# pl.legend()
#
# pl.figure('P(k) zoom',figsize=(10,8))
# pl.loglog()
# pl.plot(k_camb,Pk_camb,label='CAMB',linewidth=1.5)
# pl.xlim(1E-2,0.7)
# pl.ylim(1E2,1E5)
# pl.errorbar(k,P,yerr=sigma,label='Estimated P(k)')
# #pl.plot(k[:],fkp_stuff.P_ret2[:])#*2800)
# pl.xlabel(r'$k$ [h/Mpc]',fontsize=20)
# pl.xlabel(r'$P(k)$ [Mpc/h]$^3$',fontsize=20)
# pl.grid(True)
# pl.axvline(x=pkg.k_max/2.,color='k',label='Nyquist f.')
# pl.legend()
